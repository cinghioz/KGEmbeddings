# %%
import pandas as pd

edges = pd.read_csv("/home/cc/cc_my_mounting_point/kg/ClinGraph/ClinGraph_edges.csv", sep="\t", low_memory=False)
nodes = pd.read_csv("/home/cc/cc_my_mounting_point/kg/ClinGraph/ClinGraph_nodes.csv", sep="\t", low_memory=False)
# feats = pd.read_csv("/home/cc/cc_my_mounting_point/kg/ClinGraph/ClinGraph_features.csv", sep="\t", low_memory=False)

# %%
edges.head(5)

# %%
edges['relationship'].unique()
